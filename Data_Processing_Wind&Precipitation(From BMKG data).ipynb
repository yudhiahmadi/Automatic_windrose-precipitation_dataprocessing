# %%
import os

import pandas as pd

paths = "/content/data"
files = os.listdir(paths)

df = pd.DataFrame()
for file in range(len(files)):
    if files[file].endswith('.xlsx'):
        # Read in File
        file_df = pd.read_excel(paths + "//" + files[file],
                                sheet_name="Data Harian - Table",
                                skiprows=[0,1,2,3,4,5,6,7,40,41,42,43,44,45,46,47,48])
        # Add to just this DataFrame
        # file_df['Month'] = str(files[file])
        # Update `df`
        df = df.append(file_df, ignore_index=True)
# Out:
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# ...
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)
# <ipython-input-49-47e4d6fba138>:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(file_df, ignore_index=True)

# %%
df
# Out:
#          Tanggal     RR  ff_avg ddd_car
# 0     01-09-2020    NaN     2.0      C
# 1     02-09-2020    0.0     2.0      C
# 2     03-09-2020    6.0     2.0      NE
# 3     04-09-2020    0.0     3.0      SE
# 4     05-09-2020    0.0     2.0      C
# ...          ...    ...     ...     ...
# 9543  27-12-2007    0.0     4.0      W
# 9544  28-12-2007  120.5     5.0      W
# 9545  29-12-2007    5.1     5.0      W
# 9546  30-12-2007   32.9     3.0      N
# 9547  31-12-2007   37.2     4.0      N
#
# [9548 rows x 4 columns]

# %%
clean1 = df[df.RR != 8888]
clean1
# Out:
#          Tanggal     RR  ff_avg ddd_car
# 0     01-09-2020    NaN     2.0      C
# 1     02-09-2020    0.0     2.0      C
# 2     03-09-2020    6.0     2.0      NE
# 3     04-09-2020    0.0     3.0      SE
# 4     05-09-2020    0.0     2.0      C
# ...          ...    ...     ...     ...
# 9543  27-12-2007    0.0     4.0      W
# 9544  28-12-2007  120.5     5.0      W
# 9545  29-12-2007    5.1     5.0      W
# 9546  30-12-2007   32.9     3.0      N
# 9547  31-12-2007   37.2     4.0      N
#
# [9169 rows x 4 columns]

# %%
clean2 = clean1.dropna()
clean2
# Out:
#          Tanggal     RR  ff_avg ddd_car
# 1     02-09-2020    0.0     2.0      C
# 2     03-09-2020    6.0     2.0      NE
# 3     04-09-2020    0.0     3.0      SE
# 4     05-09-2020    0.0     2.0      C
# 7     08-09-2020    0.0     3.0      E
# ...          ...    ...     ...     ...
# 9543  27-12-2007    0.0     4.0      W
# 9544  28-12-2007  120.5     5.0      W
# 9545  29-12-2007    5.1     5.0      W
# 9546  30-12-2007   32.9     3.0      N
# 9547  31-12-2007   37.2     4.0      N
#
# [7635 rows x 4 columns]

# %%
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2000","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2001","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2002","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2003","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2004","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2005","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2006","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2007","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2008","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2009","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2010","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2011","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2012","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2013","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2014","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2015","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2016","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2017","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2018","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2019","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2020","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2021","")
clean2["Tanggal"] = clean2["Tanggal"].str.replace("2022","")
clean2
# Out:
# <ipython-input-81-05834bcf641a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2000","")
# <ipython-input-81-05834bcf641a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2001","")
# <ipython-input-81-05834bcf641a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2002","")
# <ipython-input-81-05834bcf641a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2003","")
# <ipython-input-81-05834bcf641a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2004","")
# <ipython-input-81-05834bcf641a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2005","")
# <ipython-input-81-05834bcf641a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2006","")
# <ipython-input-81-05834bcf641a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2007","")
# <ipython-input-81-05834bcf641a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2008","")
# <ipython-input-81-05834bcf641a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2009","")
# <ipython-input-81-05834bcf641a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2010","")
# <ipython-input-81-05834bcf641a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2011","")
# <ipython-input-81-05834bcf641a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2012","")
# <ipython-input-81-05834bcf641a>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2013","")
# <ipython-input-81-05834bcf641a>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2014","")
# <ipython-input-81-05834bcf641a>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2015","")
# <ipython-input-81-05834bcf641a>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2016","")
# <ipython-input-81-05834bcf641a>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2017","")
# <ipython-input-81-05834bcf641a>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2018","")
# <ipython-input-81-05834bcf641a>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2019","")
# <ipython-input-81-05834bcf641a>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2020","")
# <ipython-input-81-05834bcf641a>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2021","")
# <ipython-input-81-05834bcf641a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean2["Tanggal"] = clean2["Tanggal"].str.replace("2022","")
#      Tanggal     RR  ff_avg ddd_car
# 1     02-09-    0.0     2.0      C
# 2     03-09-    6.0     2.0      NE
# 3     04-09-    0.0     3.0      SE
# 4     05-09-    0.0     2.0      C
# 7     08-09-    0.0     3.0      E
# ...      ...    ...     ...     ...
# 9543  27-12-    0.0     4.0      W
# 9544  28-12-  120.5     5.0      W
# 9545  29-12-    5.1     5.0      W
# 9546  30-12-   32.9     3.0      N
# 9547  31-12-   37.2     4.0      N
#
# [7635 rows x 4 columns]

# %%
clean2.describe()
# Out:
#                 RR       ff_avg
# count  7635.000000  7635.000000
# mean      6.148906     2.928356
# std      16.244012     1.600850
# min       0.000000     0.000000
# 25%       0.000000     2.000000
# 50%       0.000000     3.000000
# 75%       3.700000     4.000000
# max     284.000000    13.000000

# %%
clean3 = clean2.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')
clean3

# %%
clean3.groupby(["ddd_car"]).count()
# Out:
#          Tanggal    RR  ff_avg
# ddd_car
# C            626   626     626
# E            814   814     814
# N           1487  1487    1487
# NE          1158  1158    1158
# NW           755   755     755
# S            219   219     219
# SE           585   585     585
# SW           516   516     516
# W           1475  1475    1475

# %%
clean4 = clean3[clean3["ddd_car"].str.contains("C") == False]
clean4.groupby(["ddd_car"]).count()
# Out:
#          Tanggal    RR  ff_avg
# ddd_car
# E            814   814     814
# N           1487  1487    1487
# NE          1158  1158    1158
# NW           755   755     755
# S            219   219     219
# SE           585   585     585
# SW           516   516     516
# W           1475  1475    1475

# %%
clean4["ddd_car"] = clean4["ddd_car"].str.replace("NE","45")
clean4["ddd_car"] = clean4["ddd_car"].str.replace("NW","315")
clean4["ddd_car"] = clean4["ddd_car"].str.replace("SE","135")
clean4["ddd_car"] = clean4["ddd_car"].str.replace("SW","225")
clean4["ddd_car"] = clean4["ddd_car"].str.replace("E","90")
clean4["ddd_car"] = clean4["ddd_car"].str.replace("N","0")
clean4["ddd_car"] = clean4["ddd_car"].str.replace("S","180")
clean4["ddd_car"] = clean4["ddd_car"].str.replace("W","270")
clean4
# Out:
# <ipython-input-117-d8331a5cf9df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4["ddd_car"] = clean4["ddd_car"].str.replace("NE","45")
# <ipython-input-117-d8331a5cf9df>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4["ddd_car"] = clean4["ddd_car"].str.replace("NW","315")
# <ipython-input-117-d8331a5cf9df>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4["ddd_car"] = clean4["ddd_car"].str.replace("SE","135")
# <ipython-input-117-d8331a5cf9df>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4["ddd_car"] = clean4["ddd_car"].str.replace("SW","225")
# <ipython-input-117-d8331a5cf9df>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4["ddd_car"] = clean4["ddd_car"].str.replace("E","90")
# <ipython-input-117-d8331a5cf9df>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4["ddd_car"] = clean4["ddd_car"].str.replace("N","0")
# <ipython-input-117-d8331a5cf9df>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4["ddd_car"] = clean4["ddd_car"].str.replace("S","180")
# <ipython-input-117-d8331a5cf9df>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4["ddd_car"] = clean4["ddd_car"].str.replace("W","270")
#      Tanggal     RR  ff_avg ddd_car
# 1     03-09-    6.0     2.0      45
# 2     04-09-    0.0     3.0     135
# 4     08-09-    0.0     3.0     90
# 7     14-09-    0.0     3.0      45
# 8     28-09-    0.0     3.0     90
# ...      ...    ...     ...     ...
# 7630  27-12-    0.0     4.0    270
# 7631  28-12-  120.5     5.0    270
# 7632  29-12-    5.1     5.0    270
# 7633  30-12-   32.9     3.0      0
# 7634  31-12-   37.2     4.0      0
#
# [7009 rows x 4 columns]

# %%
clean4['ddd_car'] = clean4['ddd_car'].astype('float')
clean4['Tanggal'] = clean4['Tanggal'].astype('str')
# Out:
# <ipython-input-146-40816e217bb8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4['ddd_car'] = clean4['ddd_car'].astype('float')
# <ipython-input-146-40816e217bb8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean4['Tanggal'] = clean4['Tanggal'].astype('str')

# %%
hasil = clean4.groupby(['Tanggal']).mean()
hasil.to_csv('hasil.csv')
hasil2 = pd.read_csv('hasil.csv')
hasil2
# Out:
#     Tanggal         RR    ff_avg     ddd_car
# 0    01-01-  14.636364  3.681818  261.818182
# 1    01-02-  44.109524  2.761905  240.000000
# 2    01-03-   7.564000  3.120000  156.600000
# 3    01-04-   3.733333  3.000000  157.500000
# 4    01-05-   5.544444  3.277778  162.500000
# ..      ...        ...       ...         ...
# 361  31-05-   3.927778  2.611111   90.000000
# 362  31-07-   0.000000  3.352941   79.411765
# 363  31-08-   1.909524  2.761905   57.857143
# 364  31-10-   3.572222  2.333333   72.500000
# 365  31-12-  17.340909  3.772727  222.954545
#
# [366 rows x 4 columns]

# %%
hasil2[['Tanggal1', 'Bulan', 'Kosong']] = hasil2["Tanggal"].apply(lambda x: pd.Series(str(x).split("-")))
hasil3 = hasil2.drop(['Tanggal','Kosong'],axis=1)
hasil3
# Out:
#             RR    ff_avg     ddd_car Tanggal1 Bulan
# 0    14.636364  3.681818  261.818182       01    01
# 1    44.109524  2.761905  240.000000       01    02
# 2     7.564000  3.120000  156.600000       01    03
# 3     3.733333  3.000000  157.500000       01    04
# 4     5.544444  3.277778  162.500000       01    05
# ..         ...       ...         ...      ...   ...
# 361   3.927778  2.611111   90.000000       31    05
# 362   0.000000  3.352941   79.411765       31    07
# 363   1.909524  2.761905   57.857143       31    08
# 364   3.572222  2.333333   72.500000       31    10
# 365  17.340909  3.772727  222.954545       31    12
#
# [366 rows x 5 columns]

# %%
hasil4 = hasil3.sort_values(by='Bulan', ascending=True)
hasil5 = hasil4.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')
hasil5
# Out:
#             RR    ff_avg     ddd_car Tanggal1 Bulan
# 0    14.636364  3.681818  261.818182       01    01
# 1    10.050000  3.600000  231.750000       24    01
# 2    23.061111  2.777778  230.000000       23    01
# 3    11.313636  2.590909  210.681818       22    01
# 4     6.971429  4.047619  231.428571       04    01
# ..         ...       ...         ...      ...   ...
# 361   9.019048  3.619048  244.285714       28    12
# 362   4.445000  3.200000  200.250000       04    12
# 363   6.247619  3.190476  220.714286       16    12
# 364   8.042857  3.428571  203.571429       03    12
# 365  17.340909  3.772727  222.954545       31    12
#
# [366 rows x 5 columns]

# %%
kec = hasil5['ff_avg']
arah = hasil5['ddd_car']

# %%
pip install windrose
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting windrose
#   Downloading windrose-1.8.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.9/dist-packages (from windrose) (1.22.4)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.9/dist-packages (from windrose) (3.7.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3->windrose) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3->windrose) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3->windrose) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3->windrose) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3->windrose) (4.39.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3->windrose) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3->windrose) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3->windrose) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3->windrose) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3->windrose) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3->windrose) (1.16.0)
# Installing collected packages: windrose
# Successfully installed windrose-1.8.1

# %%
from windrose import WindroseAxes
ax = WindroseAxes.from_ax()
ax.bar(arah.iloc[0:30], kec.iloc[0:30], normed=True, opening=0.8, edgecolor='white', nsector=8)
ax.set_legend()

# %%
import matplotlib.pyplot as plt
jan = kec.iloc[0:30]

jan.plot()
plt.xlabel("Hari ke- (Mulai dari Januari)")
plt.ylabel("Kecepatan Angin")
plt.title('Januari')

plt.show()

# %%
from windrose import WindroseAxes
ax = WindroseAxes.from_ax()
ax.bar(arah.iloc[91:120], kec.iloc[91:120], normed=True, opening=0.8, edgecolor='white', nsector=8)
ax.set_legend()

# %%
import matplotlib.pyplot as plt
jan = kec.iloc[91:120]

jan.plot()
plt.xlabel("Hari ke- (Mulai dari Januari)")
plt.ylabel("Kecepatan Angin")
plt.title('Juli')

plt.show()

# %%
from windrose import WindroseAxes
ax = WindroseAxes.from_ax()
ax.bar(arah.iloc[182:212], kec.iloc[182:212], normed=True, opening=0.8, edgecolor='white', nsector=8)
ax.set_legend()

# %%
import matplotlib.pyplot as plt
jan = kec.iloc[182:212]

jan.plot()
plt.xlabel("Hari ke- (Mulai dari Januari)")
plt.ylabel("Kecepatan Angin")
plt.title('Juli')

plt.show()

# %%
from windrose import WindroseAxes
ax = WindroseAxes.from_ax()
ax.bar(arah.iloc[274:304], kec.iloc[274:304], normed=True, opening=0.8, edgecolor='white', nsector=8)
ax.set_legend()

# %%
import matplotlib.pyplot as plt
jan = kec.iloc[274:304]

jan.plot()
plt.xlabel("Hari ke- (Mulai dari Januari)")
plt.ylabel("Kecepatan Angin")
plt.title('Oktober')

plt.show()

# %% [markdown]
# ##CURAH HUJAN

# %%
CH = hasil5.groupby(['Bulan']).sum()
CH
# Out:
#                RR      ff_avg      ddd_car
# Bulan
# 01     413.369139  107.221079  7293.198329
# 02     503.202908   94.652400  6095.435180
# 03     202.589842  102.742156  6119.925018
# 04     130.313491   85.870060  4222.112741
# 05     130.362117   88.163465  3175.278534
# 06      91.973773   90.705335  2815.298161
# 07      64.301971   99.336149  2654.883238
# 08      58.413129   94.509490  2412.830910
# 09      53.460886   86.238375  2202.428820
# 10     103.447929   77.290535  2858.256999
# 11     146.746882   85.129566  4209.617638
# 12     217.989664  102.686323  6916.846130

# %%
CH.to_csv('Curah_Hujan.csv')
CH2 = pd.read_csv('Curah_Hujan.csv')

# %%
import seaborn as sns

fig = plt.figure(figsize = (14, 6))

# # creating the bar plot
plt.bar(CH2['Bulan'], CH2['RR'], color ='maroon',
        width = 0.6)
 
plt.xlabel("Bulan")
plt.ylabel("Rata-rata Jumlah Curah Hujan (mm)")
plt.title("Rata-rata Jumlah Curah Hujan Bulanan")
plt.axhline(y=100, color='b', ls='--',label='Curah Hujan Rendah')
plt.axhline(y=300, color='y', ls='--',label='Curah Hujan Sedang')
plt.axhline(y=500, color='r', ls='--',label='Curah Hujan Tinggi')
plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0, title='Kategori :')
plt.show()
